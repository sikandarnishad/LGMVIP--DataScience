# %% [markdown]
# # Import Library

# %%
import cv2

# %% [markdown]
# Read Image

# %%
image = cv2.imread("modi.jpg")

# %% [markdown]
# To show or Display image

# %%
cv2.imshow("Prime Minister", image)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
#  # RGB format

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(rgb)

# %% [markdown]
# # Gray Format

# %%
gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[222, 222, 222, ..., 145, 144, 144],
#        [222, 222, 222, ..., 145, 144, 144],
#        [222, 222, 222, ..., 145, 144, 144],
#        ...,
#        [ 33,  33,  33, ..., 202, 202, 202],
#        [ 30,  30,  30, ..., 202, 202, 202],
#        [ 30,  30,  30, ..., 202, 202, 202]], dtype=uint8)

# %%
plt.imshow(gray_image)

# %% [markdown]
# # Blurr Format

# %%
blur = cv2.GaussianBlur(gray_image,(21,21),0)
plt.imshow(blur)

# %%
inverted_blurred = 255 - blur
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2.imshow("Sketch", pencil_sketch)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Pencil Image Format

# %%
cv2.imshow("original image", image)
cv2.imshow("pencil sketch", pencil_sketch)
cv2.waitKey(0)
# Out:
# -1
